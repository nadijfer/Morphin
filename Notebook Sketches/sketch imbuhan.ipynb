# %%
kata = 'meapit' # harusnya mengapit
fixed = '[FIXED]'

if kata.startswith('meng'):
    if kata[4] in ('a', 'i', 'u', 'e', 'o', 'g', 'h', 'kh'):
        fixed = kata
    else:
        print('DARI MENG-')
        if kata[4] in ('c', 'd', 'j'):
            fixed = 'men' + kata[4:]
        elif kata[4] in ('b', 'f', 'v'):
            fixed = 'mem' + kata[4:]
        elif kata[4] in ('r', 'l', 'w', 'y', 'm', 'n', 'ng', 'ny'):
            fixed = 'me' + kata[4:]
elif kata.startswith('men'):
    if kata[3] in ('c', 'd', 'j'):
        fixed = kata
    else:
        print('DARI MEN-')
        if kata[3] in ('b', 'f', 'v'):
            fixed = 'mem' + kata[3:]
        elif kata[3] in ('r', 'l', 'w', 'y', 'm', 'n', 'ng', 'ny'):
            fixed = 'me' + kata[3:]
        elif kata[3] in ('a', 'i', 'u', 'e', 'o', 'g', 'h', 'kh'):
            fixed = 'meng' + kata[3:]
elif kata.startswith('mem'):
    if kata[3] in ('b', 'f', 'v'):
        fixed = kata
    else:
        print('DARI MEM-')
        if kata[3] in ('c', 'd', 'j'):
            fixed = 'men' + kata[3:]
        elif kata[3] in ('r', 'l', 'w', 'y', 'm', 'n', 'ng', 'ny'):
            fixed = 'me' + kata[3:]
        elif kata[3] in ('a', 'i', 'u', 'e', 'o', 'g', 'h', 'kh'):
            fixed = 'meng' + kata[3:]
elif kata.startswith('me'):
    if kata[2] in ('r', 'l', 'w', 'y', 'm', 'n', 'ng', 'ny'):
        fixed = kata
    else:
        print('DARI ME-')
        if kata[2] in ('c', 'd', 'j'):
            fixed = 'men' + kata[2:]
        elif kata[2] in ('b', 'f', 'v'):
            fixed = 'me' + kata[2:]
        elif kata[2] in ('a', 'i', 'u', 'e', 'o', 'g', 'h', 'kh'):
            fixed = 'meng' + kata[2:]

print(fixed)
# Out:
# DARI ME-
# mengapit

# %%
def imbuhan_awalan(kata):
    if kata.startswith('meng'):
        if kata[4] in ('a', 'i', 'u', 'e', 'o', 'g', 'h', 'kh'):
            fixed = kata
        else:
            print('DARI MENG-')
            if kata[4] in ('c', 'd', 'j'):
                fixed = 'men' + kata[4:]
            elif kata[4] in ('b', 'f', 'v'):
                fixed = 'mem' + kata[4:]
            elif kata[4] in ('r', 'l', 'w', 'y', 'm', 'n', 'ng', 'ny'):
                fixed = 'me' + kata[4:]
    elif kata.startswith('men'):
        if kata[3] in ('c', 'd', 'j'):
            fixed = kata
        else:
            print('DARI MEN-')
            if kata[3] in ('b', 'f', 'v'):
                fixed = 'mem' + kata[3:]
            elif kata[3] in ('r', 'l', 'w', 'y', 'm', 'n', 'ng', 'ny'):
                fixed = 'me' + kata[3:]
            elif kata[3] in ('a', 'i', 'u', 'e', 'o', 'g', 'h', 'kh'):
                fixed = 'meng' + kata[3:]
    elif kata.startswith('mem'):
        if kata[3] in ('b', 'f', 'v'):
            fixed = kata
        else:
            print('DARI MEM-')
            if kata[3] in ('c', 'd', 'j'):
                fixed = 'men' + kata[3:]
            elif kata[3] in ('r', 'l', 'w', 'y', 'm', 'n', 'ng', 'ny'):
                fixed = 'me' + kata[3:]
            elif kata[3] in ('a', 'i', 'u', 'e', 'o', 'g', 'h', 'kh'):
                fixed = 'meng' + kata[3:]
    elif kata.startswith('me'):
        if kata[2] in ('r', 'l', 'w', 'y', 'm', 'n', 'ng', 'ny'):
            fixed = kata
        else:
            print('DARI ME-')
            if kata[2] in ('c', 'd', 'j'):
                fixed = 'men' + kata[2:]
            elif kata[2] in ('b', 'f', 'v'):
                fixed = 'me' + kata[2:]
            elif kata[2] in ('a', 'i', 'u', 'e', 'o', 'g', 'h', 'kh'):
                fixed = 'meng' + kata[2:]
    return fixed

# %%
print(
    imbuhan_awalan('mengdapatkan'),
    imbuhan_awalan('memluas'),
)
# Out:
# DARI MENG-
# DARI MEM-
# mendapatkan meluas

# %%
kata = 'judul nya'

kata[:-3] # -nya, -kan
fixed_list = kata.split()
fixed = "".join(fixed_list)
fixed
# Out:
# 'judulnya'

# %%
kalimat = 'yang seharusnya buku buku terdapat di judul nya'
kata2 = kalimat.split()
kata2
# Out:
# ['yang', 'seharusnya', 'buku', 'buku', 'terdapat', 'di', 'judul', 'nya']

# %%
from morphin import imbuhan

awalan = imbuhan.perbaiki_awalan
print(awalan('mengdapatkan'))

perbaiki_kalimat = imbuhan.kalimat_awalan
kalimat = 'Ia akan mengdapatkan amanat dari presiden'
print(perbaiki_kalimat(kalimat))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from morphin import imbuhan
#       3 awalan = imbuhan.perbaiki_awalan
#       4 print(awalan('mengdapatkan'))
#
# ModuleNotFoundError: No module named 'morphin'
