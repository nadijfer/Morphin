# %%
# Out:
# an ya
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 5
#       3 for i in range(len(teks)):
#       4     teks = teks[i:]
# ----> 5     if teks[i] == 'y':
#       6         print(teks)
#
# IndexError: string index out of range
